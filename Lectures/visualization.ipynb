# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

mpg = sns.load_dataset('mpg')
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    str
#  8   name          398 non-null    str
# dtypes: float64(4), int64(3), str(2)
# memory usage: 28.1 KB

# %% [markdown]
# # Anatomy of a Matplotlib Plot
#
# ```text
# Figure (the whole canvas)
#
# ├─ Axes (the plot area with data)
# │  ├─ X-axis
# │  ├─ Y-axis
# │  ├─ Title
# │  ├─ Legend
# │  └─ Data (lines, points, bars, etc.)
# ```

# %% [markdown]
# ## Ways to Create a Plots:
# 1. **Using `plt.plot()`**: This is the most common way to create a plot. It allows you to create line plots, scatter plots, bar plots, etc.
#
# 2. **Using `plt.subplots()`**: This method creates a figure and a set of subplots. It is useful when you want to create multiple plots in the same figure.

# %%
mpg_by_year = mpg.groupby('model_year')['mpg'].mean()
years = mpg_by_year.index  # X-axis
average_mpg = mpg_by_year.values  # Y-axis

# %%
# Create a line plot to visualize the average MPG over model years
plt.plot(years, average_mpg)
plt.title('Average MPG Over Model Year')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(['Average MPG'])
plt.show()

# %%
# scatter plot to show the relationship or correlation between horsepower and miles per gallon
plt.scatter(mpg['horsepower'], mpg['mpg'])
plt.title('Horsepower vs. MPG')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.show()

# %%
# Bar plot to show the average MPG for each origin
mpg_by_origin = mpg.groupby('origin')['mpg'].mean() 
origins = mpg_by_origin.index  # X-axis
average_mpg = mpg_by_origin.values  # Y-axis
plt.bar(origins, average_mpg)
plt.title('Average MPG by Origin')
plt.xlabel('Origin')
plt.ylabel('Average MPG')
plt.show()

# %% [markdown]
# ## More complex : figure, axes, and subplots. It allows for more control over the layout and appearance of the plots.

# %% [markdown]
# # Matplotlib Plot Patterns
#
# ## Single Plot Pattern
#
# ```python
# fig, ax = plt.subplots()
#
# ax.set_title("Title")
# ax.set_xlabel("X-axis label")
# ax.set_ylabel("Y-axis label")
#
# ax.plot(x, y)  # Plotting the data
# ```
#
# ### Structure
#
# ```text
# Figure
# │
# └── Axes
#     ├── Title
#     ├── X-axis Label
#     ├── Y-axis Label
#     └── Data (plot)
# ```
#
# ---
#
# ## Multiple Plots Pattern
#
# ```python
# fig, axes = plt.subplots(nrows=2, ncols=2)
#
# axes[0, 0].plot(x1, y1)  # First subplot
# axes[0, 1].plot(x2, y2)  # Second subplot
# axes[1, 0].plot(x3, y3)  # Third subplot
# axes[1, 1].plot(x4, y4)  # Fourth subplot
# ```
#
# ### Structure
#
# ```text
# Figure
# │
# ├── Axes[0,0] → First subplot
# ├── Axes[0,1] → Second subplot
# ├── Axes[1,0] → Third subplot
# └── Axes[1,1] → Fourth subplot
# ```
#
# ### Notes
#
# In this example, a **2×2 grid of subplots** is created.
#
# The `axes` variable is a **2D array of Axes objects**, allowing each subplot to be accessed and customized independently:
#
# ```python
# axes[row, column]
# ```
#
# Examples:
#
# ```python
# axes[0, 0].set_title("Plot 1")
# axes[1, 1].set_xlabel("Time")
# ```
#
# ---
#
# # Customizing Plots
#
# Matplotlib provides many options for customizing plots:
#
# - 🎨 Changing colors, line styles, and markers
# - 📏 Adding grid lines
# - 📐 Setting axis limits
# - 📝 Adding annotations
# - 📋 Customizing legends
# - 📊 Adjusting figure size and layout
# - 📈 Using different plot types:
#   - Line plots
#   - Scatter plots
#   - Bar charts
#   - Histograms
#   - Box plots
#   - Pie charts
#
# ---
#
# ## Example Customization
#
# ```python
# plt.figure(figsize=(8, 5))
#
# plt.plot(
#     x,
#     y,
#     color="blue",
#     linestyle="--",
#     marker="o",
#     label="Sales"
# )
#
# plt.title("Monthly Sales")
# plt.xlabel("Month")
# plt.ylabel("Revenue")
# plt.grid(True)
# plt.legend()
#
# plt.show()
# ```
#
# ---
#
# ## Key Takeaway
#
# > **Figure** = the entire canvas
# > **Axes** = an individual plotting area inside the figure
#
# Most Matplotlib work involves:
# 1. Creating a Figure and Axes.
# 2. Plotting data on the Axes.
# 3. Customizing the plot.
# 4. Displaying or saving the figure.

# %% [markdown]
# # Where Visualization Fits in Your Workflow
#
# ```text
# THE COMPLETE DATA ANALYSIS PIPELINE:
#
# +-----------+    +-----------+    +---------------+    +---------------+    +-----------+
# |  Day 1    | -> |  Day 2    | -> |    Day 3      | -> |    Day 4      | -> |  Day 5    |
# |   LOAD    |    |  FILTER   |    |  PREPROCESS   |    |  VISUALIZE    |    |  MODEL    |
# | EXPLORE   |    |  SELECT   |    |    CLEAN      |    |   PRESENT     |    | PREDICT   |
# +-----------+    +-----------+    +---------------+    +---------------+    +-----------+
#       |                |                  |                    |
#       |                |                  |                    |
#       v                v                  v                    v
#
#  head(), shape     loc, iloc       fillna(), encode     plt, sns
#  info(), describe  filtering       scale, engineer      charts!
# ```
#
# ---
#
# ## Visualization Serves Two Purposes
#
# ### 1. Exploration → Understand Your Data (for YOU)
#
# Questions to answer:
#
# - What patterns exist?
# - Are there any outliers?
# - How is the data distributed?
# - Are there relationships between variables?
#
# ---
#
# ### 2. Communication → Tell the Story (for OTHERS)
#
# Communicate:
#
# - What the data says
# - Why it matters
# - Key insights and recommendations
#
# > "Here's what the data says. Here's why it matters."
#
# ---
#
# ## Key Takeaway
#
# **Visualization is both:**
#
# - 🔍 A tool for **exploration**
# - 📢 A tool for **communication**

# %%
# Anscombe's Quartet - The Famous Example
anscombe = sns.load_dataset('anscombe')

# Show statistics for each dataset
print("Statistics for Anscombe's Quartet:")
print("=" * 60)
for dataset in ['I', 'II', 'III', 'IV']:
    data = anscombe[anscombe['dataset'] == dataset]
    print(f"\nDataset {dataset}:")
    print(f"  X mean: {data['x'].mean():.2f} | Y mean: {data['y'].mean():.2f}")
    print(f"  X std: {data['x'].std():.2f} | Y std: {data['y'].std():.2f}")
    corr = data['x'].corr(data['y'])
    print(f"  Correlation: {corr:.3f}")

print("\n" + "=" * 60)
print("The statistics are nearly IDENTICAL!")
# Out:
# Statistics for Anscombe's Quartet:
# ============================================================
#
# Dataset I:
#   X mean: 9.00 | Y mean: 7.50
#   X std: 3.32 | Y std: 2.03
#   Correlation: 0.816
#
# Dataset II:
#   X mean: 9.00 | Y mean: 7.50
#   X std: 3.32 | Y std: 2.03
#   Correlation: 0.816
#
# Dataset III:
#   X mean: 9.00 | Y mean: 7.50
#   X std: 3.32 | Y std: 2.03
#   Correlation: 0.816
#
# Dataset IV:
#   X mean: 9.00 | Y mean: 7.50
#   X std: 3.32 | Y std: 2.03
#   Correlation: 0.817
#
# ============================================================
# The statistics are nearly IDENTICAL!

# %%
# Now VISUALIZE the four datasets
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

datasets = ['I', 'II', 'III', 'IV']
positions = [(0, 0), (0, 1), (1, 0), (1, 1)]

for dataset, (row, col) in zip(datasets, positions):
    data = anscombe[anscombe['dataset'] == dataset]
    ax = axes[row, col]
    ax.scatter(data['x'], data['y'], s=80, alpha=0.7)
    ax.set_title(f'Dataset {dataset}', fontsize=14, fontweight='bold')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_xlim(0, 20)
    ax.set_ylim(0, 14)

    # Add regression line
    z = np.polyfit(data['x'], data['y'], 1)
    p = np.poly1d(z)
    ax.plot(data['x'].sort_values(), p(data['x'].sort_values()), color='red', alpha=0.8, linewidth=2)

plt.suptitle("Anscombe's Quartet: Same Statistics, Different Stories!", 
    fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("Same mean, same variance, same correlation - but WILDLY different data!")
# Out:
# Same mean, same variance, same correlation - but WILDLY different data!

# %% [markdown]
# # The Purpose of Different Chart Types
#
# ```text
# CHOOSING THE RIGHT CHART:
#
# ┌────────────────────────────────────────────────────────────────────────────┐
# │                                                                            │
# │  LINE CHART                                                                │
# │  ----------                                                                │
# │  Purpose: Show TRENDS over time                                            │
# │  Use when: Data changes over a sequence (time, order)                      │
# │  Example: Temperature over a week, stock prices over a year                │
# │                                                                            │
# │  BAR CHART                                                                 │
# │  ---------                                                                 │
# │  Purpose: COMPARE categories                                               │
# │  Use when: Comparing distinct groups                                       │
# │  Example: Sales by region, grades by subject                               │
# │                                                                            │
# │  HISTOGRAM                                                                 │
# │  ---------                                                                 │
# │  Purpose: Show DISTRIBUTION of one variable                                │
# │  Use when: Understanding how values are spread out                         │
# │  Example: Age distribution, test score distribution                        │
# │                                                                            │
# │  SCATTER PLOT                                                              │
# │  ------------                                                              │
# │  Purpose: Show RELATIONSHIP between two variables                          │
# │  Use when: Exploring correlations or patterns                              │
# │  Example: Height vs weight, study time vs grades                           │
# │                                                                            │
# │                                                                            │
# └────────────────────────────────────────────────────────────────────────────┘
# ```

# %% [markdown]
# # Additional Chart Types
#
# ```text
# HISTOGRAM
# ─────────
#
# Purpose: Show DISTRIBUTION of one variable
#
# Use when: Understanding how values are spread out
#
# Example: Age distribution, test score distribution
#
#
# BOX PLOT
# ────────
#
# Purpose: Compare DISTRIBUTIONS across groups
#
# Use when: Comparing spread and outliers across categories
#
# Example: Salary by department, scores by class
# ```

# %% [markdown]
# # Part 2: Matplotlib Fundamentals
#
# ## The Foundation of Python Visualization

# %% [markdown]
# # Line Plots: Showing Trends Over Time

# %%
# Create sample data: Temperature over a week
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temperatures = [72, 74, 76, 80, 82, 78, 75]

print("Temperature data:")
for day, temp in zip(days, temperatures):
    print(f" {day}: {temp} F")
# Out:
# Temperature data:
#  Mon: 72 F
#  Tue: 74 F
#  Wed: 76 F
#  Thu: 80 F
#  Fri: 82 F
#  Sat: 78 F
#  Sun: 75 F

# %%
# LIVE CODING: Basic Line Plot
# ---
# Create a line plot with:
#    - plt.plot(x_data, y_data)
#    - plt.title('...')
#    - plt.xlabel('...')
#    - plt.ylabel('...')
#    - plt.show()

plt.plot(days, temperatures)
plt.title("Temperature Variation Over a Week")
plt.xlabel("Day")
plt.ylabel("Temperature (F)")
plt.show()
