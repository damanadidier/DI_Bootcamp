# %%
import pandas as pd
import numpy as np
import data_profiling
from data_profiling import ProfileReport

# %%
df = pd.read_csv('heart_disease_uci.csv')

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_file("heart_disease_report.html")
print("Data profiling report generated: heart_disease_report.html")
# Out:
# 100%|██████████| 16/16 [00:00<00:00, 422.81it/s]00:01, 11.70it/s, Describe variable: num]
# Summarize dataset: 100%|██████████| 62/62 [00:01<00:00, 33.44it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  6.04it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 92.84it/s]
# Data profiling report generated: heart_disease_report.html
