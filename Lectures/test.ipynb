# %%
import numpy as np
from scipy import stats

# Sample data (engagement time in minutes)
sample_data = [12, 14, 11, 15,15,15,16,15, 18, 20, 22, 25, 30,15,15, 35,100]

# Performing a one-sample t-test
t_statistic, p_value = stats.ttest_1samp(sample_data, 15)
print(f"T-statistic: {t_statistic}, P-value: {p_value}")

# Interpreting the result
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# T-statistic: 1.607097568843346, P-value: 0.12758521339124237
# Fail to reject the null hypothesis
