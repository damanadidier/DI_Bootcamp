# %%
# Exercise 1: Basic Usage of SciPy
# Task: Import the SciPy library and explore its version.
import scipy
print("SciPy version:", scipy.__version__)
# Out:
# SciPy version: 1.17.1

# %%
# Exercise 2: Descriptive Statistics
# Task: Given a sample dataset, calculate the mean, median, variance, and standard deviation using SciPy.
# Sample Dataset:
# data = [12, 15, 13, 12, 18, 20, 22, 21]
import numpy as np
from scipy import stats
data = [12, 15, 13, 12, 18, 20, 22, 21]
mean = np.mean(data)
median = np.median(data)
variance = np.var(data, ddof=1)  # Sample variance
std_dev = np.std(data, ddof=1)  # Sample standard deviation
print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 17.125
# Standard Deviation: 4.138236339311712

# %%
# Exercise 3: Understanding Distributions
# Task: Generate a normal distribution using SciPy with a mean of 50 and a standard deviation of 10. Plot this distribution.
# Code Example:
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# complete your code here
# Parameters for the normal distribution
mean = 50
std_dev = 10
# Generate a range of x values
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
# Generate the normal distribution values
pdf = norm.pdf(x, mean, std_dev)
# Plot the normal distribution
plt.figure(figsize=(10, 6))
plt.plot(x, pdf, label='Normal Distribution', color='blue')
plt.title('Normal Distribution (mean=50, std_dev=10)')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid()
plt.legend()
plt.show()

# %%
# Exercise 4: T-Test Application
# Task: Perform a T-test on two sets of randomly generated data.
# Code Example:
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 10, 100)

# complete your code here
t_statistic, p_value = stats.ttest_ind(data1, data2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: -6.668636425125666
# P-value: 2.516227337512705e-10

# %%
# Exercise 5: Linear Regression Analysis
# Objective: Apply linear regression to a dataset and interpret the results.

# Task: Given a dataset of housing prices (house_prices) and their corresponding sizes (house_sizes), use linear regression to predict the price of a house given its size.
# Dataset:
# house_sizes: [50, 70, 80, 100, 120] (in square meters)
# house_prices: [150,000, 200,000, 210,000, 250,000, 280,000] (in currency units)
# Questions:
# 1. What is the slope and intercept of the regression line?
from scipy.stats import linregress
house_sizes = [50, 70, 80, 100, 120]
house_prices = [150000, 200000, 210000, 250000, 280000]
slope, intercept, r_value, p_value, std_err = linregress(house_sizes, house_prices)
print("Slope:", slope)
print("Intercept:", intercept)

# 2. Predict the price of a house that is 90 square meters.
predicted_price = intercept + slope * 90
print("Predicted price for a 90 square meter house:", predicted_price)
# Out:
# Slope: 1828.7671232876712
# Intercept: 64383.56164383562
# Predicted price for a 90 square meter house: 228972.60273972602

# %% [markdown]
# # 3. Interpret the meaning of the slope in the context of housing prices.
# The slope in the context of housing prices represents the rate at which the price of a house changes with respect to a specific variable, such as the size of the house, the number of bedrooms, or the location. For example, if we are looking at the relationship between the size of a house (in square feet) and its price, the slope would indicate how much the price increases for each additional square foot. A positive slope would suggest that larger houses tend to be more expensive, while a negative slope would indicate that larger houses tend to be less expensive. The magnitude of the slope can also provide insight into how strongly the variable affects housing prices.

# %%
# Exercise 6: Understanding ANOVA
# Objective: Test understanding of ANOVA and its application.

# Task: Three different fertilizers are applied to three separate groups of plants to test their effectiveness. The growth in centimeters is recorded.
# Dataset:
# fertilizer_1: [5, 6, 7, 6, 5]
# fertilizer_2: [7, 8, 7, 9, 8]
# fertilizer_3: [4, 5, 4, 3, 4]
# Questions:
# Perform an ANOVA test on the given data. What are the F-value and P-value?
from scipy.stats import f_oneway
fertilizer_1 = [5, 6, 7, 6, 5]
fertilizer_2 = [7, 8, 7, 9, 8]
fertilizer_3 = [4, 5, 4, 3, 4]
f_value, p_value = f_oneway(fertilizer_1, fertilizer_2, fertilizer_3)
print("F-value:", f_value)
print("P-value:", p_value)

# Based on the P-value, do the fertilizers have significantly different effects on plant growth?
if p_value < 0.05:
    print("The fertilizers have significantly different effects on plant growth.")
else:    
    print("The fertilizers do not have significantly different effects on plant growth.")
# Out:
# F-value: 28.52631578947368
# P-value: 2.7542672098048448e-05
# The fertilizers have significantly different effects on plant growth.

# %% [markdown]
# # Explain what would happen if the P-value were greater than 0.05.
# If the P-value were greater than 0.05, it would indicate that there is not enough evidence to reject the null hypothesis. In the context of housing prices, this would mean that the variable being tested (e.g., size of the house, number of bedrooms) does not have a statistically significant effect on the price of the house. As a result, we would fail to conclude that there is a meaningful relationship between the variable and housing prices, and we might consider other factors or variables that could influence housing prices instead.

# %%
# Exercise 7: Probability Distributions (Optional)
# Work with a binomial distribution: calculate probabilities for different numbers of successes.
# Example: Calculating the probability of getting exactly 5 heads in 10 coin flips.
from scipy.stats import binom
# Parameters for the binomial distribution
n = 10  # number of trials
p = 0.5  # probability of success (getting heads)
k = 5  # number of successes (getting exactly 5 heads)
# Calculate the probability of getting exactly 5 heads
probability = binom.pmf(k, n, p)
print("Probability of getting exactly 5 heads in 10 flips:", probability)
# Out:
# Probability of getting exactly 5 heads in 10 flips: 0.2460937500000002

# %%
# Exercise 8: Correlation Coefficients (Optional)
# Calculate the Pearson and Spearman correlation coefficients between two variables in a dataset.
# Example in code: data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})
import pandas as pd
data = pd.DataFrame({'age': [23, 25, 30, 35, 40], 'income': [35000, 40000, 50000, 60000, 70000]})
# Calculate Pearson correlation coefficient
pearson_corr = data['age'].corr(data['income'], method='pearson')
print("Pearson correlation coefficient:", pearson_corr)
# Calculate Spearman correlation coefficient
spearman_corr = data['age'].corr(data['income'], method='spearman')
print("Spearman correlation coefficient:", spearman_corr)
# Out:
# Pearson correlation coefficient: 0.9996907452347202
# Spearman correlation coefficient: 0.9999999999999999
